# %% [markdown]
# <a href="https://colab.research.google.com/github/benjarojas/ADA-Informes/blob/main/OptimalBST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Optimal Binary Search Tree
#
# **Entrada:** Un arreglo $K$ **ordenado** de $n$ claves $K = [k_1, k_2, \ldots , k_n]$. Cada clave $k_i$ tiene asociada una probabilidad $p_i$ de ser buscada, por lo que en la entrada también tenemos un arreglo $P$ de probabilidades, que quedaría como $P = [p_1, p_2, \ldots, p_n]$
#
# **Salida:** Un **árbol de búsqueda** cuya distribución de nodos **minimice la cantidad media de nodos** que debe visitar el algoritmo de búsqueda para encontrar una clave.
#
# Un **árbol binario de búsqueda óptimo** es **árbol de búsqueda** donde el coste medio de buscar un elemento se reduce al mínimo, con esto logramos que incluso con **aproximaciones de los costos de búsqueda se aceleran considerablemente las búsquedas medias.**

# %% [markdown]
# # 2. Código

# %% [markdown]
# ## 2.1 OptimalBST Recursivo

# %%
from termcolor import colored

def optimalCost(prob, i, j, verbose=False): 
  global call_count

  # caso base
  if j < i:     
    return 0
  if j == i:
    if(verbose): print(f"Caso base (j == i). Retornando prob[{i}] = {colored(f'{prob[i]}', 'blue')}\n") 
    return prob[i]

  # sumamos todas las probabilidades del sub-arreglo
  fsum = auxSum(prob, i, j)
  if(verbose): print(f"Suma de las probabilidades entre p[{i}] y p[{j}]: {fsum}")
  
  minCost = float('inf') # inicializamos en infinito para la primera comparación
  for r in range(i, j + 1): # iteramos por cada índice del arreglo, r será la raíz del árbol
    call_count = call_count + 1
    A = optimalCost(prob, i, r - 1, verbose=verbose)
    if(verbose): print(f"Calculamos recursivamente el coste óptimo entre {colored(f'p[{i}]', 'red')} y {colored(f'p[{r-1}]', 'red')}: {colored(f'{A}', 'green')}")
      
    call_count = call_count + 1
    B = optimalCost(prob, r + 1, j, verbose=verbose)
    if(verbose): print(f"Calculamos recursivamente el coste óptimo entre {colored(f'p[{r+1}]', 'red')} y {colored(f'p[{j}]', 'red')}: {colored(f'{A}', 'green')}")

    cost = A + B
    if(verbose): print(f"Costo calculado: {cost}\n")

    if cost < minCost:
      if(verbose): print(f"El costo calculado {cost} es menor que el costo mínimo anterior {minCost}\n")
      minCost = cost
     
  if(verbose): print(f"Costo óptimo: {minCost + fsum}\n")
  return minCost + fsum

def recursiveOptBST(arrayKeys, prob, n, verbose=False):
  return optimalCost(prob, 0, n - 1, verbose=verbose)
 
# función auxiliar para sumar todas las probabilidades
# entre los índices i y j de un arreglo
def auxSum(prob, i, j):
  s = 0
  for k in range(i, j + 1):
    s += prob[k]
  return s

# %%
k=[1, 2, 3, 4, 5]
p=[0.35, 0.2, 0.15, 0.2, 0.1]
call_count = 0
n = len(k)
print(f"Costo mínimo esperado: {recursiveOptBST(k,p,n)}")
print(f"Llamadas recursivas: {call_count}")
# Out:
# Costo mínimo esperado: 2.05
# Llamadas recursivas: 134

# %% [markdown]
# ## 2.2 OptimalBST Bottom-Up (Programación Dinámica)

# %%
import numpy as np
from termcolor import colored

def optimalBST(arrayKeys, arrayProb,verbose=False):
  global subCount
  cantKeys = len(arrayKeys)  #cantidad de llaves

  if(verbose):
    print(f"{str(colored('Keys:', 'red'))} {arrayKeys}")
    print(f"{str(colored('Probabilidades:', 'blue'))} {arrayProb}\n")

  costMatrix = np.zeros((cantKeys+2,cantKeys+1)) 
  probMatrix = np.zeros((cantKeys+2,cantKeys+1))

  # Iteramos la matriz por sobre la diagonal principal
  for i in range(0,cantKeys+1):
    for j in range(1, cantKeys+1-i): 
      probMatrix[j][i+j] = probMatrix[j][i+j-1] + arrayProb[i+j-1] #se calcula la probabilidad en la posición evaluada

      if(verbose):
        print(f"{str(colored(f'Probabilidad para probMatrix[{j}][{i+j}]: {probMatrix[j][i+j]}', 'blue'))}")

      minCost = float('inf')
      for r in range (j,i+j+1): # iteramos por todas las raíces posibles de esa posición
        subCount += 1
        cost = probMatrix[j][i+j] + costMatrix[j][r-1] + costMatrix[r+1][i+j] # calculamos el costo

        if(verbose):
          print(f"Costo para {str(colored(f'r={r}','red'))}: {str(colored(f'{cost}', 'green'))}")

        if(cost<minCost): #se busca el mínimo costo entre las raíces trabajadas
          minCost = cost

      costMatrix[j][i+j] = minCost
      if(verbose == True):
          print(f"{str(colored('Menor costo de las raices calculadas de', 'green'))} {str(colored(f'probMatrix[{j}][{i+j}]', 'blue'))}{str(colored(f': {minCost}', 'green'))}\n")
  
  if(verbose):
    print(f"{str(colored('Matriz de probabilidades:', 'blue'))} \n{probMatrix}\n")
    print(f"{str(colored('Matriz de costos:', 'green'))} \n{costMatrix}\n")
    print(f"{str(colored(f'Costo mínimo esperado: {costMatrix[1][cantKeys]}', 'green'))}")
  
  return(costMatrix[1][cantKeys])

# %%
k=[1, 2, 3, 4, 5]
p=[0.35, 0.2, 0.15, 0.2, 0.1]
subCount = 0
print(f"Costo mínimo esperado: {optimalBST(k,p)}")
print(f"Cantidad de subproblemas: {subCount}")
# Out:
# Costo mínimo esperado: 2.05
# Cantidad de subproblemas: 35

# %% [markdown]
# ## 2.3 Generador de Instancias

# %%
import random

def optimal_bst_instance_generator(n):
    keys = sorted(random.sample(range(1, 100), n))
    arr = np.random.random(n*2+1)
    arr /= arr.sum()
    p = list(arr[:n]) # Probabilidad de las claves
    return keys, p

# %% [markdown]
# # 3. Descripción de los algoritmos

# %% [markdown]
# ## 3.1 OptimalBST Recursivo

# %% [markdown]
# ### 3.1.1 Descripción
#
# Recibimos como entrada un arreglo de probabilidades y un par de índices $i, j$ que corresponden al **sub-árbol cuyo costo óptimo se calcula en la llamada recursiva**.
#
# El algoritmo ejecuta las siguientes operaciones:
#
#
#
# 1.   Se calcula la suma de todas las probabilidades en el árbol $prob[i \ldots j]$
# 2.   Iterativamente tomamos cada nodo $i$ como raíz $r$ del árbol
# 3.   Recursivamente calculamos el coste óptimo para el **sub-árbol izquierdo** y **derecho** a partir de la raíz $r$.
# 4.   El **costo esperado** se calcula como el **costo del sub-arbol izquierdo** + **costo del sub-arbol derecho** + **la suma de las probabilidades**.
# 5.   Por cada iteración se compara el **costo mínimo** con el **costo mínimo anterior** y se guarda el que sea menor.
# 6.   Se reconstruye el árbol a partir de la raíz y los sub-arboles que **minimicen el costo**.
# 7.   Retornam el **costo mínimo esperado**.

# %% [markdown]
# ### 3.1.2 Ejemplo de ejecución

# %% [markdown]
# ### 3.1.3 Ejecución paso a paso (`verbose=True`)

# %%
keys, prob = optimal_bst_instance_generator(5)
recursiveOptBST(keys, prob, len(prob), verbose=True)
# Out:
# Suma de las probabilidades entre p[0] y p[4]: 0.4918520002654707
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Suma de las probabilidades entre p[1] y p[4]: 0.46425833735304106
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Suma de las probabilidades entre p[2] y p[4]: 0.4065081411183751
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0
# Suma de las probabilidades entre p[3] y p[4]: 0.23323369630239169
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0
# Costo calculado: 0.10225912007285631
#
# El costo calculado 0.10225912007285631 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0.13097457622953537
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.13097457622953537
# Costo calculado: 0.13097457622953537
#
# Costo óptimo: 0.33549281637524797
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[4]: 0
# Costo calculado: 0.33549281637524797
#
# El costo calculado 0.33549281637524797 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.17327444481598342
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0.17327444481598342
# Costo calculado: 0.27553356488883973
#
# El costo calculado 0.27553356488883973 es menor que el costo mínimo anterior 0.33549281637524797
#
# Suma de las probabilidades entre p[2] y p[3]: 0.30424902104551876
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0
# Costo calculado: 0.13097457622953537
#
# El costo calculado 0.13097457622953537 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.17327444481598342
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.17327444481598342
# Costo calculado: 0.17327444481598342
#
# Costo óptimo: 0.4352235972750541
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[3]: 0.4352235972750541
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.4352235972750541
# Costo calculado: 0.4352235972750541
#
# Costo óptimo: 0.6820417060072148
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[4]: 0
# Costo calculado: 0.6820417060072148
#
# El costo calculado 0.6820417060072148 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Suma de las probabilidades entre p[3] y p[4]: 0.23323369630239169
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0
# Costo calculado: 0.10225912007285631
#
# El costo calculado 0.10225912007285631 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0.13097457622953537
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.13097457622953537
# Costo calculado: 0.13097457622953537
#
# Costo óptimo: 0.33549281637524797
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[4]: 0.05775019623466596
# Costo calculado: 0.3932430126099139
#
# El costo calculado 0.3932430126099139 es menor que el costo mínimo anterior 0.6820417060072148
#
# Suma de las probabilidades entre p[1] y p[2]: 0.23102464105064938
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0
# Costo calculado: 0.17327444481598342
#
# El costo calculado 0.17327444481598342 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0.05775019623466596
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior 0.17327444481598342
#
# Costo óptimo: 0.28877483728531533
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[2]: 0.28877483728531533
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0.28877483728531533
# Costo calculado: 0.39103395735817165
#
# El costo calculado 0.39103395735817165 es menor que el costo mínimo anterior 0.3932430126099139
#
# Suma de las probabilidades entre p[1] y p[3]: 0.36199921728018475
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Suma de las probabilidades entre p[2] y p[3]: 0.30424902104551876
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0
# Costo calculado: 0.13097457622953537
#
# El costo calculado 0.13097457622953537 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.17327444481598342
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.17327444481598342
# Costo calculado: 0.17327444481598342
#
# Costo óptimo: 0.4352235972750541
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[3]: 0
# Costo calculado: 0.4352235972750541
#
# El costo calculado 0.4352235972750541 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0.05775019623466596
# Costo calculado: 0.18872477246420133
#
# El costo calculado 0.18872477246420133 es menor que el costo mínimo anterior 0.4352235972750541
#
# Suma de las probabilidades entre p[1] y p[2]: 0.23102464105064938
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0
# Costo calculado: 0.17327444481598342
#
# El costo calculado 0.17327444481598342 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0.05775019623466596
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior 0.17327444481598342
#
# Costo óptimo: 0.28877483728531533
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[2]: 0.28877483728531533
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.28877483728531533
# Costo calculado: 0.28877483728531533
#
# Costo óptimo: 0.5507239897443861
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[3]: 0.5507239897443861
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.5507239897443861
# Costo calculado: 0.5507239897443861
#
# Costo óptimo: 0.8552922947112127
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[4]: 0
# Costo calculado: 0.8552922947112127
#
# El costo calculado 0.8552922947112127 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Suma de las probabilidades entre p[2] y p[4]: 0.4065081411183751
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0
# Suma de las probabilidades entre p[3] y p[4]: 0.23323369630239169
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0
# Costo calculado: 0.10225912007285631
#
# El costo calculado 0.10225912007285631 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0.13097457622953537
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.13097457622953537
# Costo calculado: 0.13097457622953537
#
# Costo óptimo: 0.33549281637524797
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[4]: 0
# Costo calculado: 0.33549281637524797
#
# El costo calculado 0.33549281637524797 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.17327444481598342
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0.17327444481598342
# Costo calculado: 0.27553356488883973
#
# El costo calculado 0.27553356488883973 es menor que el costo mínimo anterior 0.33549281637524797
#
# Suma de las probabilidades entre p[2] y p[3]: 0.30424902104551876
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0
# Costo calculado: 0.13097457622953537
#
# El costo calculado 0.13097457622953537 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.17327444481598342
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.17327444481598342
# Costo calculado: 0.17327444481598342
#
# Costo óptimo: 0.4352235972750541
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[3]: 0.4352235972750541
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.4352235972750541
# Costo calculado: 0.4352235972750541
#
# Costo óptimo: 0.6820417060072148
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[4]: 0.02759366291242967
# Costo calculado: 0.7096353689196445
#
# El costo calculado 0.7096353689196445 es menor que el costo mínimo anterior 0.8552922947112127
#
# Suma de las probabilidades entre p[0] y p[1]: 0.08534385914709564
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0.02759366291242967
# Costo calculado: 0.02759366291242967
#
# El costo calculado 0.02759366291242967 es menor que el costo mínimo anterior 0.05775019623466596
#
# Costo óptimo: 0.11293752205952531
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[1]: 0.11293752205952531
# Suma de las probabilidades entre p[3] y p[4]: 0.23323369630239169
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0
# Costo calculado: 0.10225912007285631
#
# El costo calculado 0.10225912007285631 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0.13097457622953537
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.13097457622953537
# Costo calculado: 0.13097457622953537
#
# Costo óptimo: 0.33549281637524797
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[4]: 0.11293752205952531
# Costo calculado: 0.4484303384347733
#
# El costo calculado 0.4484303384347733 es menor que el costo mínimo anterior 0.7096353689196445
#
# Suma de las probabilidades entre p[0] y p[2]: 0.25861830396307905
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Suma de las probabilidades entre p[1] y p[2]: 0.23102464105064938
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0
# Costo calculado: 0.17327444481598342
#
# El costo calculado 0.17327444481598342 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0.05775019623466596
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior 0.17327444481598342
#
# Costo óptimo: 0.28877483728531533
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[2]: 0
# Costo calculado: 0.28877483728531533
#
# El costo calculado 0.28877483728531533 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.02759366291242967
# Costo calculado: 0.2008681077284131
#
# El costo calculado 0.2008681077284131 es menor que el costo mínimo anterior 0.28877483728531533
#
# Suma de las probabilidades entre p[0] y p[1]: 0.08534385914709564
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0.02759366291242967
# Costo calculado: 0.02759366291242967
#
# El costo calculado 0.02759366291242967 es menor que el costo mínimo anterior 0.05775019623466596
#
# Costo óptimo: 0.11293752205952531
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[1]: 0.11293752205952531
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0.11293752205952531
# Costo calculado: 0.11293752205952531
#
# El costo calculado 0.11293752205952531 es menor que el costo mínimo anterior 0.2008681077284131
#
# Costo óptimo: 0.3715558260226044
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[2]: 0.3715558260226044
# Caso base (j == i). Retornando prob[4] = 0.10225912007285631
#
# Calculamos recursivamente el coste óptimo entre p[4] y p[4]: 0.3715558260226044
# Costo calculado: 0.4738149460954607
#
# Suma de las probabilidades entre p[0] y p[3]: 0.3895928801926144
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Suma de las probabilidades entre p[1] y p[3]: 0.36199921728018475
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Suma de las probabilidades entre p[2] y p[3]: 0.30424902104551876
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0
# Costo calculado: 0.13097457622953537
#
# El costo calculado 0.13097457622953537 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.17327444481598342
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.17327444481598342
# Costo calculado: 0.17327444481598342
#
# Costo óptimo: 0.4352235972750541
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[3]: 0
# Costo calculado: 0.4352235972750541
#
# El costo calculado 0.4352235972750541 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0.05775019623466596
# Costo calculado: 0.18872477246420133
#
# El costo calculado 0.18872477246420133 es menor que el costo mínimo anterior 0.4352235972750541
#
# Suma de las probabilidades entre p[1] y p[2]: 0.23102464105064938
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0
# Costo calculado: 0.17327444481598342
#
# El costo calculado 0.17327444481598342 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0.05775019623466596
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior 0.17327444481598342
#
# Costo óptimo: 0.28877483728531533
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[2]: 0.28877483728531533
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.28877483728531533
# Costo calculado: 0.28877483728531533
#
# Costo óptimo: 0.5507239897443861
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[3]: 0
# Costo calculado: 0.5507239897443861
#
# El costo calculado 0.5507239897443861 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Suma de las probabilidades entre p[2] y p[3]: 0.30424902104551876
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0
# Costo calculado: 0.13097457622953537
#
# El costo calculado 0.13097457622953537 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.17327444481598342
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.17327444481598342
# Costo calculado: 0.17327444481598342
#
# Costo óptimo: 0.4352235972750541
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[3]: 0.02759366291242967
# Costo calculado: 0.46281726018748376
#
# El costo calculado 0.46281726018748376 es menor que el costo mínimo anterior 0.5507239897443861
#
# Suma de las probabilidades entre p[0] y p[1]: 0.08534385914709564
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0.02759366291242967
# Costo calculado: 0.02759366291242967
#
# El costo calculado 0.02759366291242967 es menor que el costo mínimo anterior 0.05775019623466596
#
# Costo óptimo: 0.11293752205952531
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[1]: 0.11293752205952531
# Caso base (j == i). Retornando prob[3] = 0.13097457622953537
#
# Calculamos recursivamente el coste óptimo entre p[3] y p[3]: 0.11293752205952531
# Costo calculado: 0.24391209828906069
#
# El costo calculado 0.24391209828906069 es menor que el costo mínimo anterior 0.46281726018748376
#
# Suma de las probabilidades entre p[0] y p[2]: 0.25861830396307905
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Suma de las probabilidades entre p[1] y p[2]: 0.23102464105064938
# Calculamos recursivamente el coste óptimo entre p[1] y p[0]: 0
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0
# Costo calculado: 0.17327444481598342
#
# El costo calculado 0.17327444481598342 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0.05775019623466596
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0.05775019623466596
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior 0.17327444481598342
#
# Costo óptimo: 0.28877483728531533
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[2]: 0
# Costo calculado: 0.28877483728531533
#
# El costo calculado 0.28877483728531533 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Caso base (j == i). Retornando prob[2] = 0.17327444481598342
#
# Calculamos recursivamente el coste óptimo entre p[2] y p[2]: 0.02759366291242967
# Costo calculado: 0.2008681077284131
#
# El costo calculado 0.2008681077284131 es menor que el costo mínimo anterior 0.28877483728531533
#
# Suma de las probabilidades entre p[0] y p[1]: 0.08534385914709564
# Calculamos recursivamente el coste óptimo entre p[0] y p[-1]: 0
# Caso base (j == i). Retornando prob[1] = 0.05775019623466596
#
# Calculamos recursivamente el coste óptimo entre p[1] y p[1]: 0
# Costo calculado: 0.05775019623466596
#
# El costo calculado 0.05775019623466596 es menor que el costo mínimo anterior inf
#
# Caso base (j == i). Retornando prob[0] = 0.02759366291242967
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[0]: 0.02759366291242967
# Calculamos recursivamente el coste óptimo entre p[2] y p[1]: 0.02759366291242967
# Costo calculado: 0.02759366291242967
#
# El costo calculado 0.02759366291242967 es menor que el costo mínimo anterior 0.05775019623466596
#
# Costo óptimo: 0.11293752205952531
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[1]: 0.11293752205952531
# Calculamos recursivamente el coste óptimo entre p[3] y p[2]: 0.11293752205952531
# Costo calculado: 0.11293752205952531
#
# El costo calculado 0.11293752205952531 es menor que el costo mínimo anterior 0.2008681077284131
#
# Costo óptimo: 0.3715558260226044
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[2]: 0.3715558260226044
# Calculamos recursivamente el coste óptimo entre p[4] y p[3]: 0.3715558260226044
# Costo calculado: 0.3715558260226044
#
# Costo óptimo: 0.6335049784816751
#
# Calculamos recursivamente el coste óptimo entre p[0] y p[3]: 0.6335049784816751
# Calculamos recursivamente el coste óptimo entre p[5] y p[4]: 0.6335049784816751
# Costo calculado: 0.6335049784816751
#
# Costo óptimo: 0.940282338700244
# 0.940282338700244

# %% [markdown]
# ## 3.2 OptimalBST Bottom-Up (Programación Dinámica)

# %% [markdown]
# ### 3.2.1 Descripción

# %% [markdown]
# Recibimos como entrada un **arreglo de claves** y un **arreglo de probabilidades** *(cada clave tiene asociada una probabilidad)*.
#
#
# 1.   Primero el algoritmo crea **2 matrices de dimensión $(n+1) \times (n+2)$** donde $n$ es la **cantidad de keys** del árbol.
# 2.   Las matrices corresponden a **costMatrix** y **probMatrix**, es decir, las matrices de costo y de probabilidad.
# 3.   Se calcula el valor de $\text{costMatrix}[i][j]$ y de $\text{probMatrix}[i][j]$ desde la diagonal principal hacia arriba.
# 4.   $\text{costMatrix}[i][j] = {probMatrix}[i][j] + {costMatrix}[i][r-1] + {costMatrix}[r+1][j]$ donde $r$ itera desde $i$ hasta $j$.
# 5.   ${probMatrix}[i][j] = {probMatrix}[i][j-1] + {prob}[j-1]$
# 6.   Retornamos el valor contenido en {costMatrix}[1][n], que corresponde al costo esperado del árbol óptimo.

# %% [markdown]
# ### 3.2.2 Ejemplo de ejecución

# %% [markdown]
# ### 3.2.3 Ejecución paso a paso (`verbose=True`)

# %%
keys, prob = optimal_bst_instance_generator(5)
optimalBST(keys, prob, verbose=True)
# Out:
# Keys: [13, 14, 55, 66, 76]
# Probabilidades: [0.054152098743014535, 0.08190626300374555, 0.0945626102098999, 0.12746478345713977, 0.11952812278470369]
#
# Probabilidad para probMatrix[1][1]: 0.054152098743014535
# Costo para r=1: 0.054152098743014535
# Menor costo de las raices calculadas de probMatrix[1][1]: 0.054152098743014535
#
# Probabilidad para probMatrix[2][2]: 0.08190626300374555
# Costo para r=2: 0.08190626300374555
# Menor costo de las raices calculadas de probMatrix[2][2]: 0.08190626300374555
#
# Probabilidad para probMatrix[3][3]: 0.0945626102098999
# Costo para r=3: 0.0945626102098999
# Menor costo de las raices calculadas de probMatrix[3][3]: 0.0945626102098999
#
# Probabilidad para probMatrix[4][4]: 0.12746478345713977
# Costo para r=4: 0.12746478345713977
# Menor costo de las raices calculadas de probMatrix[4][4]: 0.12746478345713977
#
# Probabilidad para probMatrix[5][5]: 0.11952812278470369
# Costo para r=5: 0.11952812278470369
# Menor costo de las raices calculadas de probMatrix[5][5]: 0.11952812278470369
#
# Probabilidad para probMatrix[1][2]: 0.1360583617467601
# Costo para r=1: 0.21796462475050565
# Costo para r=2: 0.19021046048977464
# Menor costo de las raices calculadas de probMatrix[1][2]: 0.19021046048977464
#
# Probabilidad para probMatrix[2][3]: 0.17646887321364546
# Costo para r=2: 0.2710314834235453
# Costo para r=3: 0.258375136217391
# Menor costo de las raices calculadas de probMatrix[2][3]: 0.258375136217391
#
# Probabilidad para probMatrix[3][4]: 0.22202739366703966
# Costo para r=3: 0.34949217712417946
# Costo para r=4: 0.3165900038769396
# Menor costo de las raices calculadas de probMatrix[3][4]: 0.3165900038769396
#
# Probabilidad para probMatrix[4][5]: 0.24699290624184345
# Costo para r=4: 0.36652102902654715
# Costo para r=5: 0.3744576896989832
# Menor costo de las raices calculadas de probMatrix[4][5]: 0.36652102902654715
#
# Probabilidad para probMatrix[1][3]: 0.23062097195665998
# Costo para r=1: 0.488996108174051
# Costo para r=2: 0.37933568090957437
# Costo para r=3: 0.4208314324464346
# Menor costo de las raices calculadas de probMatrix[1][3]: 0.37933568090957437
#
# Probabilidad para probMatrix[2][4]: 0.3039336566707852
# Costo para r=2: 0.6205236605477248
# Costo para r=3: 0.5133047031316705
# Costo para r=4: 0.5623087928881763
# Menor costo de las raices calculadas de probMatrix[2][4]: 0.5133047031316705
#
# Probabilidad para probMatrix[3][5]: 0.34155551645174337
# Costo para r=3: 0.7080765454782905
# Costo para r=4: 0.555646249446347
# Costo para r=5: 0.658145520328683
# Menor costo de las raices calculadas de probMatrix[3][5]: 0.555646249446347
#
# Probabilidad para probMatrix[1][4]: 0.3580857554137997
# Costo para r=1: 0.8713904585454703
# Costo para r=2: 0.7288278580337538
# Costo para r=3: 0.6757609993607141
# Costo para r=4: 0.7374214363233741
# Menor costo de las raices calculadas de probMatrix[1][4]: 0.6757609993607141
#
# Probabilidad para probMatrix[2][5]: 0.4234617794554889
# Costo para r=2: 0.9791080289018359
# Costo para r=3: 0.8718890714857817
# Costo para r=4: 0.8013650384575836
# Costo para r=5: 0.9367664825871594
# Menor costo de las raices calculadas de probMatrix[2][5]: 0.8013650384575836
#
# Probabilidad para probMatrix[1][5]: 0.4776138781985034
# Costo para r=1: 1.278978916656087
# Costo para r=2: 1.087412226387865
# Costo para r=3: 1.0343453677148253
# Costo para r=4: 0.9764776818927815
# Costo para r=5: 1.1533748775592176
# Menor costo de las raices calculadas de probMatrix[1][5]: 0.9764776818927815
#
# Matriz de probabilidades:
# [[0.         0.         0.         0.         0.         0.        ]
#  [0.         0.0541521  0.13605836 0.23062097 0.35808576 0.47761388]
#  [0.         0.         0.08190626 0.17646887 0.30393366 0.42346178]
#  [0.         0.         0.         0.09456261 0.22202739 0.34155552]
#  [0.         0.         0.         0.         0.12746478 0.24699291]
#  [0.         0.         0.         0.         0.         0.11952812]
#  [0.         0.         0.         0.         0.         0.        ]]
#
# Matriz de costos:
# [[0.         0.         0.         0.         0.         0.        ]
#  [0.         0.0541521  0.19021046 0.37933568 0.675761   0.97647768]
#  [0.         0.         0.08190626 0.25837514 0.5133047  0.80136504]
#  [0.         0.         0.         0.09456261 0.31659    0.55564625]
#  [0.         0.         0.         0.         0.12746478 0.36652103]
#  [0.         0.         0.         0.         0.         0.11952812]
#  [0.         0.         0.         0.         0.         0.        ]]
#
# Costo mínimo esperado: 0.9764776818927815
# 0.9764776818927815
